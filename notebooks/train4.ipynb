# %%
import sys
import os

sys.path.append(os.path.abspath("D:\\Lab\\DL-HW3"))

# %%
# %cd DL-HW3/scripts
# !git stash
# !git pull origin main
# Out:
# D:\Lab\DL-HW3\scripts
# Already up to date.
# From https://github.com/AnimateBow4809/DL-HW3
#  * branch            main       -> FETCH_HEAD

# %%
# skip connection and trans
# %run main.py
# Out:
# D:\Environmants\TAI-HW1\Lib\site-packages\albumentations\core\validation.py:114: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# Global seed set to 42. Deterministic algorithms enabled.
# Train size: 160 (DS1: 80, DS2: 80) | Augmented
# Val size: 20 (DS1: 10, DS2: 10) | Pristine
# Test size: 20 (DS1: 10, DS2: 10) | Pristine
# Counting class pixels: 100%|█████████████████████████████████████████████████████████| 160/160 [00:37<00:00,  4.24it/s]
# Class 0: 0.2596
# Class 1: 0.8974
# Class 2: 12.3868
# Class 3: 17.9219
# Class 4: 78.1027
# Class 5: 14.7368
# Class 6: 1.1873
# Class 7: 0.5067
# Epoch 1/30 [Train]: 100%|████████████████████████████████████████████████████████████| 160/160 [00:43<00:00,  3.67it/s]
# Epoch 1/30 | Train Loss: 1.6438, Train IoU: 0.1799 | Val Loss: 1.5488, Val IoU: 0.2427
# ...

# %%
# %run test.py
# Out:
# Global seed set to 42. Deterministic algorithms enabled.
# Train size: 160 (DS1: 80, DS2: 80) | Augmented
# Val size: 20 (DS1: 10, DS2: 10) | Pristine
# Test size: 20 (DS1: 10, DS2: 10) | Pristine
# Successfully loaded model weights from: ../models/saved/model_epoch_30_bs_1_skip_True_expansion_trans_bn_False.pth
#
# --- Starting Evaluation on Test Set ---
# Final Test Loss: 0.4890
# Final Test Overall IoU: 0.4618
# --- Per-Class IoU ---
# Class 0 IoU: 0.9470 | Total Pixels in Test Set: 605966
# Class 1 IoU: 0.5416 | Total Pixels in Test Set: 183585
# Class 2 IoU: 0.3160 | Total Pixels in Test Set: 15784
# Class 3 IoU: 0.1640 | Total Pixels in Test Set: 7440
# Class 4 IoU: 0.1574 | Total Pixels in Test Set: 2913
# Class 5 IoU: 0.3171 | Total Pixels in Test Set: 21023
# Class 6 IoU: 0.5907 | Total Pixels in Test Set: 143274
# Class 7 IoU: 0.6605 | Total Pixels in Test Set: 330735
