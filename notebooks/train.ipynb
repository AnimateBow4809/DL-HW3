# %%
# %pip install torchmetrics
# %pip install albumentations
# %pip install torchinfo
# %pip install pycocotools

# %%
# %cd DL-HW3/scripts
# !git stash
# !git pull origin main

# %%
import sys
import os

sys.path.append(os.path.abspath("D:\\Lab\\DL-HW3"))

# %% [markdown]
# # Question 1

# %%
# skip connection and up
# %run main.py

# %%
# %run test.py

# %%
# skip connection and up
# %run main.py

# %% [markdown]
# # Tests

# %%
# %run test.py

# %%
# %run test.py

# %%
# %run test.py

# %%
# %run test.py
