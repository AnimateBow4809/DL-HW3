# %%
# %pip install torchmetrics
# %pip install albumentations
# %pip install torchinfo
# %pip install pycocotools
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: D:\Environmants\TAI-HW1\Scripts\python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: D:\Environmants\TAI-HW1\Scripts\python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: D:\Environmants\TAI-HW1\Scripts\python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: D:\Environmants\TAI-HW1\Scripts\python.exe -m pip install --upgrade pip

# %%
# !git clone https://github.com/AnimateBow4809/DL-HW3.git

# %%
import sys
import os

sys.path.append(os.path.abspath("D:\\Lab\\DL-HW3"))

# %%
# %cd DL-HW3/scripts
# Out:
# D:\Lab\DL-HW3\scripts

# %%
# %run main.py
# Out:
# Global seed set to 42. Deterministic algorithms enabled.
# Train size: 160 (DS1: 80, DS2: 80)
# Val size: 20 (DS1: 10, DS2: 10)
# Test size: 20 (DS1: 10, DS2: 10)
# Epoch 1/10 [Train]: 100%|██████████████████████████████████████████████████████████████| 16/16 [00:48<00:00,  3.03s/it]
# Epoch 1/10 | Train Loss: 1.6712, Train IoU: 0.0627 | Val Loss: 1.2956, Val IoU: 0.1680
# Epoch 2/10 [Train]: 100%|██████████████████████████████████████████████████████████████| 16/16 [00:47<00:00,  2.96s/it]
# Epoch 2/10 | Train Loss: 1.0171, Train IoU: 0.1764 | Val Loss: 0.7942, Val IoU: 0.1961
# Epoch 3/10 [Train]: 100%|██████████████████████████████████████████████████████████████| 16/16 [00:48<00:00,  3.03s/it]
# Epoch 3/10 | Train Loss: 0.7805, Train IoU: 0.2164 | Val Loss: 0.7241, Val IoU: 0.2327
# Epoch 4/10 [Train]: 100%|██████████████████████████████████████████████████████████████| 16/16 [00:48<00:00,  3.03s/it]
# ...
