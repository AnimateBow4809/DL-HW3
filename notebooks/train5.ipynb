# %%
import sys
import os

sys.path.append(os.path.abspath("D:\\Lab\\DL-HW3"))

# %%
# %cd DL-HW3/scripts
# !git stash
# !git pull origin main
# Out:
# D:\Lab\DL-HW3\scripts
# Already up to date.
# From https://github.com/AnimateBow4809/DL-HW3
#  * branch            main       -> FETCH_HEAD

# %%
# skip connection and trans and bn
# %run main.py
# Out:
# Global seed set to 42. Deterministic algorithms enabled.
# Train size: 160 (DS1: 80, DS2: 80) | Augmented
# Val size: 20 (DS1: 10, DS2: 10) | Pristine
# Test size: 20 (DS1: 10, DS2: 10) | Pristine
# D:\Environmants\TAI-HW1\Lib\site-packages\albumentations\core\validation.py:114: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# Counting class pixels: 100%|█████████████████████████████████████████████████████████| 160/160 [00:35<00:00,  4.55it/s]
# Class 0: 0.2597
# Class 1: 0.8937
# Class 2: 12.3367
# Class 3: 18.1590
# Class 4: 78.6511
# Class 5: 14.7459
# Class 6: 1.1708
# Class 7: 0.5103
# Epoch 1/30 [Train]: 100%|████████████████████████████████████████████████████████████| 160/160 [00:48<00:00,  3.33it/s]
# Epoch 1/30 | Train Loss: 1.4956, Train IoU: 0.2132 | Val Loss: 1.4126, Val IoU: 0.2035
# ...

# %%
# skip connection and trans and bn
# %run main.py
# Out:
# Global seed set to 42. Deterministic algorithms enabled.
# Train size: 160 (DS1: 80, DS2: 80) | Augmented
# Val size: 20 (DS1: 10, DS2: 10) | Pristine
# Test size: 20 (DS1: 10, DS2: 10) | Pristine
# Counting class pixels: 100%|███████████████████████████████████████████████████████████| 10/10 [00:35<00:00,  3.51s/it]
# Class 0: 0.2596
# Class 1: 0.8999
# Class 2: 12.1902
# Class 3: 17.7026
# Class 4: 77.9031
# Class 5: 14.6853
# Class 6: 1.1777
# Class 7: 0.5080
# Epoch 1/30 [Train]: 100%|██████████████████████████████████████████████████████████████| 10/10 [00:40<00:00,  4.02s/it]
# Epoch 1/30 | Train Loss: 1.6957, Train IoU: 0.1788 | Val Loss: 1.9458, Val IoU: 0.2525
# Epoch 2/30 [Train]: 100%|██████████████████████████████████████████████████████████████| 10/10 [00:39<00:00,  3.99s/it]
# Epoch 2/30 | Train Loss: 1.3170, Train IoU: 0.2525 | Val Loss: 2.2839, Val IoU: 0.2134
# ...
