# %%
import sys
import os
import matplotlib.pyplot as plt

sys.path.append(os.path.abspath("D:\\Lab\\DL-HW3"))
plt.style.use('default')

# %%
# %cd DL-HW3/scripts
# !git stash
# !git pull origin main
# Out:
# D:\Lab\DL-HW3\scripts
# Already up to date.
# From https://github.com/AnimateBow4809/DL-HW3
#  * branch            main       -> FETCH_HEAD

# %%
# skip connection and trans and bn and no focal bad batch size
# %run main.py
# Out:
# D:\Environmants\TAI-HW1\Lib\site-packages\albumentations\core\validation.py:114: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# Global seed set to 42. Deterministic algorithms enabled.
# Train size: 160 (DS1: 80, DS2: 80) | Augmented
# Val size: 20 (DS1: 10, DS2: 10) | Pristine
# Test size: 20 (DS1: 10, DS2: 10) | Pristine
# Counting class pixels: 100%|█████████████████████████████████████████████████████████| 160/160 [00:35<00:00,  4.50it/s]
# Class 0: 0.2580
# Class 1: 0.9063
# Class 2: 12.3737
# Class 3: 18.7029
# Class 4: 77.1466
# Class 5: 14.6726
# Class 6: 1.1816
# Class 7: 0.5105
# Epoch 1/30 [Train]: 100%|████████████████████████████████████████████████████████████| 160/160 [00:43<00:00,  3.64it/s]
# Epoch 1/30 | Train Loss: 1.5095, Train IoU: 0.2109 | Val Loss: 1.5645, Val IoU: 0.1817
# ...

# %%
# skip connection and trans and bn and no focal
# %run main.py
# Out:
# Global seed set to 42. Deterministic algorithms enabled.
# {'data': {'dataset1_path': '../data/dataset/dataset1', 'dataset2_path': '../data/dataset/dataset2', 'batch_size': 16}, 'model': {'device': 'cuda', 'skip_connection': True, 'expansion': 'trans', 'batch_normalization': True, 'epochs': 30, 'num_classes': 8, 'early_stopping': False}, 'optimizer': {'use_focal_loss': True, 'weight_decay': 0.0001, 'lr': 0.0001}}
# Train size: 160 (DS1: 80, DS2: 80) | Augmented
# Val size: 20 (DS1: 10, DS2: 10) | Pristine
# Test size: 20 (DS1: 10, DS2: 10) | Pristine
# Counting class pixels: 100%|███████████████████████████████████████████████████████████| 10/10 [00:35<00:00,  3.50s/it]
# Class 0: 0.2618
# Class 1: 0.8880
# Class 2: 12.4266
# Class 3: 17.5599
# Class 4: 77.2739
# Class 5: 14.6199
# Class 6: 1.1709
# Class 7: 0.5048
# Epoch 1/30 [Train]: 100%|██████████████████████████████████████████████████████████████| 10/10 [00:40<00:00,  4.03s/it]
# ...

# %%
# skip connection and trans and bn and focal
# %run main.py
# Out:
# Global seed set to 42. Deterministic algorithms enabled.
# {'data': {'dataset1_path': '../data/dataset/dataset1', 'dataset2_path': '../data/dataset/dataset2', 'batch_size': 16}, 'model': {'device': 'cuda', 'skip_connection': True, 'expansion': 'trans', 'batch_normalization': True, 'epochs': 30, 'num_classes': 8, 'early_stopping': False, 'path': None}, 'optimizer': {'use_focal_loss': True, 'weight_decay': 0.0001, 'lr': 0.0001}}
# Train size: 160 (DS1: 80, DS2: 80) | Augmented
# Val size: 20 (DS1: 10, DS2: 10) | Pristine
# Test size: 20 (DS1: 10, DS2: 10) | Pristine
# Counting class pixels: 100%|███████████████████████████████████████████████████████████| 10/10 [00:34<00:00,  3.50s/it]
# Class 0: 0.2596
# Class 1: 0.8945
# Class 2: 12.2836
# Class 3: 17.6433
# Class 4: 77.4657
# Class 5: 14.9028
# Class 6: 1.1764
# Class 7: 0.5098
# Epoch 1/30 [Train]: 100%|██████████████████████████████████████████████████████████████| 10/10 [00:40<00:00,  4.00s/it]
# ...

# %%
# %run test.py
# Out:
# Global seed set to 42. Deterministic algorithms enabled.
# Train size: 160 (DS1: 80, DS2: 80) | Augmented
# Val size: 20 (DS1: 10, DS2: 10) | Pristine
# Test size: 20 (DS1: 10, DS2: 10) | Pristine
# D:\Environmants\TAI-HW1\Lib\site-packages\albumentations\core\validation.py:114: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# Successfully loaded model weights from: ../models/saved/model_focal_True_epoch_30_bs_16_skip_True_expansion_trans_bn_True.pth
#
# --- Starting Evaluation on Test Set ---
# Final Test Loss: 0.7152
# Final Test Overall IoU: 0.5568
# --- Per-Class IoU ---
# Class 0 IoU: 0.9381 | Total Pixels in Test Set: 605966
# Class 1 IoU: 0.5324 | Total Pixels in Test Set: 183585
# Class 2 IoU: 0.3670 | Total Pixels in Test Set: 15784
# Class 3 IoU: 0.3386 | Total Pixels in Test Set: 7440
# Class 4 IoU: 0.4639 | Total Pixels in Test Set: 2913
# ...
