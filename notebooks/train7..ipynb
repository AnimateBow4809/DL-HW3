# %%
# %pip install ultralytics
# Out:
# ...
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.3/1.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.3/1.3 MB ? eta -:--:--
#    ---------------- ----------------------- 0.5/1.3 MB 579.8 kB/s eta 0:00:02
#    ---------------- ----------------------- 0.5/1.3 MB 579.8 kB/s eta 0:00:02
#    ------------------------ --------------- 0.8/1.3 MB 587.0 kB/s eta 0:00:01
#    ------------------------ --------------- 0.8/1.3 MB 587.0 kB/s eta 0:00:01
#    -------------------------------- ------- 1.0/1.3 MB 612.6 kB/s eta 0:00:01
#    -------------------------------- ------- 1.0/1.3 MB 612.6 kB/s eta 0:00:01
#    ---------------------------------------- 1.3/1.3 MB 615.1 kB/s  0:00:02
# ...

# %%
# %cd DL-HW3/
# Out:
# D:\Lab\DL-HW3

# %%
from ultralytics import YOLO
import numpy as np
import torch
import matplotlib.pyplot as plt
from tqdm import tqdm

from utils.mask_utils import CLASS_NAMES

plt.style.use('default')

model = YOLO('yolov8n.pt')
results = model.train(
    data='coco8.yaml',
    epochs=50,
    freeze=10,
    plots=True
)
sample_image = 'https://ultralytics.com/images/bus.jpg'
prediction = model.predict(source=sample_image, show=True, save=True)
# Out:
# New https://pypi.org/project/ultralytics/8.4.60 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.59  Python-3.13.13 torch-2.11.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3090, 24576MiB)
# ...

# %%
import matplotlib.pyplot as plt
import cv2

sample_image = './datasets/coco8/images/val/000000000061.jpg'
results = model.predict(source=sample_image, show=False, save=True)
res_plotted = results[0].plot()
res_plotted = cv2.cvtColor(res_plotted, cv2.COLOR_BGR2RGB)
plt.imshow(res_plotted)
plt.axis('off') # Hides the axes
plt.show()
# Out:
# image 1/1 D:\Lab\DL-HW3\datasets\coco8\images\val\000000000061.jpg: 512x640 1 person, 12.0ms
# Speed: 6.5ms preprocess, 12.0ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
# Results saved to D:\Lab\DL-HW3\runs\detect\predict-2
